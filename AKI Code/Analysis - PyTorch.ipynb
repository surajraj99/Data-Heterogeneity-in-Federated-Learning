# %%
import numpy as np
import pandas as pd
import os
import pprint
import sklearn
from sklearn import preprocessing
from sklearn.decomposition import PCA
import warnings
import matplotlib
from os import listdir
import seaborn as sns
import scipy
import sys
import pickle
import miceforest as mf
warnings.filterwarnings("ignore")
import functools
from functools import reduce
from mc4.algorithm import mc4_aggregator
from copy import deepcopy

import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base

from sklearn.preprocessing import StandardScaler, MinMaxScaler
import missingpy
from sklearn.experimental import enable_iterative_imputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.metrics import brier_score_loss, precision_score, recall_score, f1_score, log_loss, roc_auc_score, auc
from collections import Counter
import torch
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm
import copy

import warnings
warnings.filterwarnings("ignore")

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import NearMiss
from collections import Counter

import shap
import matplotlib.pyplot as plt
import statsmodels.api as sm
from torch.utils.data import Dataset, DataLoader
from IPython.display import display

# %%
rs = 42

# %%
import random

def _init_fn(worker_id):
    np.random.seed(int(rs))
    
def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

seed_torch()

# %%
def find_csv_filenames( path_to_dir, suffix=".csv" ):
    filenames = listdir(path_to_dir)
    return [ filename for filename in filenames if filename.endswith( suffix ) ]

# %%
os.chdir('..')

# %%
prediction_window = '48h'

# %%
data_directory = 'AKI Data/eicu_aki/new data/'
prediction_directory = 'observation' + prediction_window + '_prediction24h/'

data_files = find_csv_filenames(data_directory+prediction_directory)

hosps = [x.replace('.csv', '') for x in data_files]

# %% [markdown]
# ### Loading in Model Performances

# %% [markdown]
# #### LR

# %%
model_directory = 'AKI Models/' + prediction_window + '/Pytorch LR/'

# %%
filename = model_directory + 'LocalModelPerformances.pckl'
performances = pickle.load(open(filename, 'rb'))
lr_local_models_performances, lr_local_models_stds, lr_local_models_roc_info = tuple(performances)

# %%
filename = model_directory + 'FedLocalModelPerformances.pckl'
performances = pickle.load(open(filename, 'rb'))
lr_fed_local_models_performances, lr_fed_local_models_stds, lr_fed_local_models_roc_info = tuple(performances)

# %%
filename = model_directory + 'AggLocalModelPerformances.pckl'
performances = pickle.load(open(filename, 'rb'))
lr_agg_local_models_performances, lr_agg_local_models_stds, lr_agg_local_models_roc_info = tuple(performances)

# %% [markdown]
# #### MLP

# %%
model_directory = 'AKI Models/' + prediction_window + '/Pytorch MLP/'

# %%
filename = model_directory + 'LocalModelPerformances.pckl'
performances = pickle.load(open(filename, 'rb'))
mlp_local_models_performances, mlp_local_models_stds, mlp_local_models_roc_info = tuple(performances)

# %%
filename = model_directory + 'FedLocalModelPerformances.pckl'
performances = pickle.load(open(filename, 'rb'))
mlp_fed_local_models_performances, mlp_fed_local_models_stds, mlp_fed_local_models_roc_info = tuple(performances)

# %%
filename = model_directory + 'AggLocalModelPerformances.pckl'
performances = pickle.load(open(filename, 'rb'))
mlp_agg_local_models_performances, mlp_agg_local_models_stds, mlp_agg_local_models_roc_info = tuple(performances)

# %% [markdown]
# ## Plotting Performances

# %% [markdown]
# ### LR

# %% [markdown]
# #### AUC Bar Plots

# %%
channel = ['Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated',
           'Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated',
           'Local', 'Pooled', 'Federated']
average_auc = []
std_auc = []
for hosp in hosps:
    average_auc.append(lr_local_models_performances[hosp][1][1])
    average_auc.append(lr_agg_local_models_performances[hosp][1][1])
    average_auc.append(lr_fed_local_models_performances[hosp][1][1])
    std_auc.append(lr_local_models_stds[hosp][1][1])
    std_auc.append(lr_agg_local_models_stds[hosp][1][1])
    std_auc.append(lr_fed_local_models_stds[hosp][1][1])

# %%
conc = np.repeat(hosps,3)
a = list(set(conc))
conc2 = [a.index(x) for x in conc]
conc2.sort()

# %%
df = pd.DataFrame({"Model Type": channel,
                  "Average AUC": average_auc,
                  "sd" : std_auc,
                  "Hospital": conc})

order = hosps
plt.figure(figsize=(10,10))
plt.ylim(0.5, 1.0)
sns.barplot(x="Hospital", y="Average AUC", hue="Model Type", data=df, ci=None, 
            order=order)

width = .25
add = [-1*width, 0 , width, -1*width, 0 , width, -1*width, 0 , width, -1*width, 0 , width, -1*width, 0 , width,
      -1*width, 0 , width, -1*width, 0 , width]
x = np.array(conc2)+np.array(add)

plt.errorbar(x = x, y = df['Average AUC'],
            yerr=df['sd'], fmt='none', c= 'black', capsize = 2)
plt.show()

# %% [markdown]
# #### AUC ROC Curves

# %%
num_rows = 3
num_cols = 3

# %%
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15,15))
fig.delaxes(axes[(2, 1)])
fig.delaxes(axes[(2, 2)])

for i, hosp in enumerate(hosps):
    fpr_l, tpr_l, t = lr_local_models_roc_info[hosp]
    roc_auc_l = auc(fpr_l, tpr_l)
    fpr_f, tpr_f, t = lr_fed_local_models_roc_info[hosp]
    roc_auc_f = auc(fpr_f, tpr_f)
    fpr_p, tpr_p, t = lr_agg_local_models_roc_info[hosp]
    roc_auc_p = auc(fpr_p, tpr_p)

    # Plot ROC curve
    ax = axes[divmod(i, num_cols)]
    ax.plot(fpr_l, tpr_l, label='Local (area = %0.3f)' % roc_auc_l)
    ax.plot(fpr_p, tpr_p, label='Pooled (area = %0.3f)' % roc_auc_p)
    ax.plot(fpr_f, tpr_f, label='Federated (area = %0.3f)' % roc_auc_f)
    ax.plot([0, 1], [0, 1], 'k--')  # random predictions curve
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.0])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('ROC: {}'.format(hosp))
    ax.legend(loc="lower right")
    
plt.tight_layout()

# %% [markdown]
# ### MLP

# %% [markdown]
# #### AUC Bar Plots

# %%
channel = ['Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated',
           'Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated', 'Local', 'Pooled', 'Federated',
           'Local', 'Pooled', 'Federated']
average_auc = []
std_auc = []
for hosp in hosps:
    average_auc.append(mlp_local_models_performances[hosp][1][1])
    average_auc.append(mlp_agg_local_models_performances[hosp][1][1])
    average_auc.append(mlp_fed_local_models_performances[hosp][1][1])
    std_auc.append(mlp_local_models_stds[hosp][1][1])
    std_auc.append(mlp_agg_local_models_stds[hosp][1][1])
    std_auc.append(mlp_fed_local_models_stds[hosp][1][1])

# %%
conc = np.repeat(hosps,3)
a = list(set(conc))
conc2 = [a.index(x) for x in conc]
conc2.sort()

# %%
df = pd.DataFrame({"Model Type": channel,
                  "Average AUC": average_auc,
                  "sd" : std_auc,
                  "Hospital": conc})

order = hosps
plt.figure(figsize=(10,10))
plt.ylim(0.5, 1.0)
sns.barplot(x="Hospital", y="Average AUC", hue="Model Type", data=df, ci=None, 
            order=order)

width = .25
add = [-1*width, 0 , width, -1*width, 0 , width, -1*width, 0 , width, -1*width, 0 , width, -1*width, 0 , width,
      -1*width, 0 , width, -1*width, 0 , width]
x = np.array(conc2)+np.array(add)

plt.errorbar(x = x, y = df['Average AUC'],
            yerr=df['sd'], fmt='none', c= 'black', capsize = 2)
plt.show()

# %% [markdown]
# #### AUC ROC Curves

# %%
num_rows = 3
num_cols = 3

# %%
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15,15))
fig.delaxes(axes[(2, 1)])
fig.delaxes(axes[(2, 2)])

for i, hosp in enumerate(hosps):
    fpr_l, tpr_l, t = mlp_local_models_roc_info[hosp]
    roc_auc_l = auc(fpr_l, tpr_l)
    fpr_f, tpr_f, t = mlp_fed_local_models_roc_info[hosp]
    roc_auc_f = auc(fpr_f, tpr_f)
    fpr_p, tpr_p, t = mlp_agg_local_models_roc_info[hosp]
    roc_auc_p = auc(fpr_p, tpr_p)

    # Plot ROC curve
    ax = axes[divmod(i, num_cols)]
    ax.plot(fpr_l, tpr_l, label='Local (area = %0.3f)' % roc_auc_l)
    ax.plot(fpr_p, tpr_p, label='Pooled (area = %0.3f)' % roc_auc_p)
    ax.plot(fpr_f, tpr_f, label='Federated (area = %0.3f)' % roc_auc_f)
    ax.plot([0, 1], [0, 1], 'k--')  # random predictions curve
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.0])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('ROC: {}'.format(hosp))
    ax.legend(loc="lower right")
    
plt.tight_layout()

# %% [markdown]
# ### Create Tables for Performances

# %% [markdown]
# #### AUC Table

# %%
lr_hosp_local_performances = []
for hosp in hosps:
    auc_string = str(lr_local_models_performances[hosp][1][1]) + " ± " + str(lr_local_models_stds[hosp][1][1])
    lr_hosp_local_performances.append(auc_string)
    
lr_hosp_pool_performances = []
for hosp in hosps:
    auc_string = str(lr_agg_local_models_performances[hosp][1][1]) + " ± " + str(lr_agg_local_models_stds[hosp][1][1])
    lr_hosp_pool_performances.append(auc_string)
    
lr_hosp_fed_performances = []
for hosp in hosps:
    auc_string = str(lr_fed_local_models_performances[hosp][1][1]) + " ± " + str(lr_fed_local_models_stds[hosp][1][1])
    lr_hosp_fed_performances.append(auc_string)

df_lr = pd.DataFrame([lr_hosp_local_performances, lr_hosp_pool_performances, lr_hosp_fed_performances], 
             columns=hosps)
df_lr['Type'] = ['Local', 'Pooled', 'Federated']
df_lr['Architecture'] = ['LR', 'LR', 'LR']
df_lr = df_lr[['Architecture', 'Type', '420', '122', '243', '252', '458', '199', '73']]

#############

mlp_hosp_local_performances = []
for hosp in hosps:
    auc_string = str(mlp_local_models_performances[hosp][1][1]) + " ± " + str(mlp_local_models_stds[hosp][1][1])
    mlp_hosp_local_performances.append(auc_string)
    
mlp_hosp_pool_performances = []
for hosp in hosps:
    auc_string = str(mlp_agg_local_models_performances[hosp][1][1]) + " ± " + str(mlp_agg_local_models_stds[hosp][1][1])
    mlp_hosp_pool_performances.append(auc_string)
    
mlp_hosp_fed_performances = []
for hosp in hosps:
    auc_string = str(mlp_fed_local_models_performances[hosp][1][1]) + " ± " + str(mlp_fed_local_models_stds[hosp][1][1])
    mlp_hosp_fed_performances.append(auc_string)

df_mlp = pd.DataFrame([mlp_hosp_local_performances, mlp_hosp_pool_performances, mlp_hosp_fed_performances], 
             columns=hosps)
df_mlp['Type'] = ['Local', 'Pooled', 'Federated']
df_mlp['Architecture'] = ['MLP', 'MLP', 'MLP']
df_mlp = df_mlp[['Architecture', 'Type', '420', '122', '243', '252', '458', '199', '73']]

# %%
df_mlp2 = df_mlp.set_index(['Architecture', 'Type'])
colsR = [('Hospitals', col) for col in df_mlp2.columns if col in hosps]
df_mlp2.columns = pd.MultiIndex.from_tuples(colsR)

df_mlp2 = df_mlp2.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
df_mlp2.set_properties(**{'text-align': 'center'})
df_mlp2
# Out:
# <style type="text/css">
# #T_8f461_ th {
#   text-align: center;
# }
# #T_8f461_row0_col0, #T_8f461_row0_col1, #T_8f461_row0_col2, #T_8f461_row0_col3, #T_8f461_row0_col4, #T_8f461_row0_col5, #T_8f461_row0_col6, #T_8f461_row1_col0, #T_8f461_row1_col1, #T_8f461_row1_col2, #T_8f461_row1_col3, #T_8f461_row1_col4, #T_8f461_row1_col5, #T_8f461_row1_col6, #T_8f461_row2_col0, #T_8f461_row2_col1, #T_8f461_row2_col2, #T_8f461_row2_col3, #T_8f461_row2_col4, #T_8f461_row2_col5, #T_8f461_row2_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_8f461_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="7">Hospitals</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >420</th>
#       <th class="col_heading level1 col1" >122</th>
#       <th class="col_heading level1 col2" >243</th>
#       <th class="col_heading level1 col3" >252</th>
#       <th class="col_heading level1 col4" >458</th>
#       <th class="col_heading level1 col5" >199</th>
#       <th class="col_heading level1 col6" >73</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Architecture</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f461_level0_row0" class="row_heading level0 row0" rowspan="3">MLP</th>
#       <th id="T_8f461_level1_row0" class="row_heading level1 row0" >Local</th>
#       <td id="T_8f461_row0_col0" class="data row0 col0" >0.693 ± 0.036</td>
#       <td id="T_8f461_row0_col1" class="data row0 col1" >0.677 ± 0.016</td>
#       <td id="T_8f461_row0_col2" class="data row0 col2" >0.8 ± 0.018</td>
#       <td id="T_8f461_row0_col3" class="data row0 col3" >0.76 ± 0.035</td>
#       <td id="T_8f461_row0_col4" class="data row0 col4" >0.723 ± 0.028</td>
#       <td id="T_8f461_row0_col5" class="data row0 col5" >0.673 ± 0.039</td>
#       <td id="T_8f461_row0_col6" class="data row0 col6" >0.709 ± 0.041</td>
#     </tr>
#     <tr>
#       <th id="T_8f461_level1_row1" class="row_heading level1 row1" >Pooled</th>
#       <td id="T_8f461_row1_col0" class="data row1 col0" >0.718 ± 0.033</td>
#       <td id="T_8f461_row1_col1" class="data row1 col1" >0.704 ± 0.025</td>
#       <td id="T_8f461_row1_col2" class="data row1 col2" >0.775 ± 0.024</td>
#       <td id="T_8f461_row1_col3" class="data row1 col3" >0.744 ± 0.028</td>
#       <td id="T_8f461_row1_col4" class="data row1 col4" >0.747 ± 0.032</td>
#       <td id="T_8f461_row1_col5" class="data row1 col5" >0.686 ± 0.048</td>
#       <td id="T_8f461_row1_col6" class="data row1 col6" >0.708 ± 0.027</td>
#     </tr>
#     <tr>
#       <th id="T_8f461_level1_row2" class="row_heading level1 row2" >Federated</th>
#       <td id="T_8f461_row2_col0" class="data row2 col0" >0.775 ± 0.027</td>
#       <td id="T_8f461_row2_col1" class="data row2 col1" >0.749 ± 0.015</td>
#       <td id="T_8f461_row2_col2" class="data row2 col2" >0.833 ± 0.017</td>
#       <td id="T_8f461_row2_col3" class="data row2 col3" >0.816 ± 0.03</td>
#       <td id="T_8f461_row2_col4" class="data row2 col4" >0.8 ± 0.024</td>
#       <td id="T_8f461_row2_col5" class="data row2 col5" >0.72 ± 0.04</td>
#       <td id="T_8f461_row2_col6" class="data row2 col6" >0.782 ± 0.017</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_lr2 = df_lr.set_index(['Architecture', 'Type'])
colsR = [('Hospitals', col) for col in df_lr2.columns if col in hosps]
df_lr2.columns = pd.MultiIndex.from_tuples(colsR)

df_lr2 = df_lr2.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
df_lr2.set_properties(**{'text-align': 'center'})
df_lr2
# Out:
# <style type="text/css">
# #T_5820c_ th {
#   text-align: center;
# }
# #T_5820c_row0_col0, #T_5820c_row0_col1, #T_5820c_row0_col2, #T_5820c_row0_col3, #T_5820c_row0_col4, #T_5820c_row0_col5, #T_5820c_row0_col6, #T_5820c_row1_col0, #T_5820c_row1_col1, #T_5820c_row1_col2, #T_5820c_row1_col3, #T_5820c_row1_col4, #T_5820c_row1_col5, #T_5820c_row1_col6, #T_5820c_row2_col0, #T_5820c_row2_col1, #T_5820c_row2_col2, #T_5820c_row2_col3, #T_5820c_row2_col4, #T_5820c_row2_col5, #T_5820c_row2_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_5820c_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="7">Hospitals</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >420</th>
#       <th class="col_heading level1 col1" >122</th>
#       <th class="col_heading level1 col2" >243</th>
#       <th class="col_heading level1 col3" >252</th>
#       <th class="col_heading level1 col4" >458</th>
#       <th class="col_heading level1 col5" >199</th>
#       <th class="col_heading level1 col6" >73</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Architecture</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5820c_level0_row0" class="row_heading level0 row0" rowspan="3">LR</th>
#       <th id="T_5820c_level1_row0" class="row_heading level1 row0" >Local</th>
#       <td id="T_5820c_row0_col0" class="data row0 col0" >0.737 ± 0.028</td>
#       <td id="T_5820c_row0_col1" class="data row0 col1" >0.712 ± 0.029</td>
#       <td id="T_5820c_row0_col2" class="data row0 col2" >0.821 ± 0.018</td>
#       <td id="T_5820c_row0_col3" class="data row0 col3" >0.769 ± 0.029</td>
#       <td id="T_5820c_row0_col4" class="data row0 col4" >0.767 ± 0.039</td>
#       <td id="T_5820c_row0_col5" class="data row0 col5" >0.677 ± 0.039</td>
#       <td id="T_5820c_row0_col6" class="data row0 col6" >0.751 ± 0.021</td>
#     </tr>
#     <tr>
#       <th id="T_5820c_level1_row1" class="row_heading level1 row1" >Pooled</th>
#       <td id="T_5820c_row1_col0" class="data row1 col0" >0.714 ± 0.023</td>
#       <td id="T_5820c_row1_col1" class="data row1 col1" >0.697 ± 0.011</td>
#       <td id="T_5820c_row1_col2" class="data row1 col2" >0.684 ± 0.039</td>
#       <td id="T_5820c_row1_col3" class="data row1 col3" >0.744 ± 0.034</td>
#       <td id="T_5820c_row1_col4" class="data row1 col4" >0.701 ± 0.011</td>
#       <td id="T_5820c_row1_col5" class="data row1 col5" >0.683 ± 0.044</td>
#       <td id="T_5820c_row1_col6" class="data row1 col6" >0.751 ± 0.021</td>
#     </tr>
#     <tr>
#       <th id="T_5820c_level1_row2" class="row_heading level1 row2" >Federated</th>
#       <td id="T_5820c_row2_col0" class="data row2 col0" >0.779 ± 0.03</td>
#       <td id="T_5820c_row2_col1" class="data row2 col1" >0.749 ± 0.016</td>
#       <td id="T_5820c_row2_col2" class="data row2 col2" >0.835 ± 0.014</td>
#       <td id="T_5820c_row2_col3" class="data row2 col3" >0.815 ± 0.026</td>
#       <td id="T_5820c_row2_col4" class="data row2 col4" >0.802 ± 0.021</td>
#       <td id="T_5820c_row2_col5" class="data row2 col5" >0.722 ± 0.038</td>
#       <td id="T_5820c_row2_col6" class="data row2 col6" >0.78 ± 0.016</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_perf_auc = pd.concat([df_lr, df_mlp])
df_perf_auc = df_perf_auc.set_index(['Architecture', 'Type'])

colsR = [('Hospitals', col) for col in df_perf_auc.columns if col in hosps]
df_perf_auc.columns = pd.MultiIndex.from_tuples(colsR)

df_perf_auc = df_perf_auc.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
df_perf_auc.set_properties(**{'text-align': 'center'})
df_perf_auc
# Out:
# <style type="text/css">
# #T_f3d3c_ th {
#   text-align: center;
# }
# #T_f3d3c_row0_col0, #T_f3d3c_row0_col1, #T_f3d3c_row0_col2, #T_f3d3c_row0_col3, #T_f3d3c_row0_col4, #T_f3d3c_row0_col5, #T_f3d3c_row0_col6, #T_f3d3c_row1_col0, #T_f3d3c_row1_col1, #T_f3d3c_row1_col2, #T_f3d3c_row1_col3, #T_f3d3c_row1_col4, #T_f3d3c_row1_col5, #T_f3d3c_row1_col6, #T_f3d3c_row2_col0, #T_f3d3c_row2_col1, #T_f3d3c_row2_col2, #T_f3d3c_row2_col3, #T_f3d3c_row2_col4, #T_f3d3c_row2_col5, #T_f3d3c_row2_col6, #T_f3d3c_row3_col0, #T_f3d3c_row3_col1, #T_f3d3c_row3_col2, #T_f3d3c_row3_col3, #T_f3d3c_row3_col4, #T_f3d3c_row3_col5, #T_f3d3c_row3_col6, #T_f3d3c_row4_col0, #T_f3d3c_row4_col1, #T_f3d3c_row4_col2, #T_f3d3c_row4_col3, #T_f3d3c_row4_col4, #T_f3d3c_row4_col5, #T_f3d3c_row4_col6, #T_f3d3c_row5_col0, #T_f3d3c_row5_col1, #T_f3d3c_row5_col2, #T_f3d3c_row5_col3, #T_f3d3c_row5_col4, #T_f3d3c_row5_col5, #T_f3d3c_row5_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_f3d3c_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="7">Hospitals</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >420</th>
#       <th class="col_heading level1 col1" >122</th>
#       <th class="col_heading level1 col2" >243</th>
#       <th class="col_heading level1 col3" >252</th>
#       <th class="col_heading level1 col4" >458</th>
#       <th class="col_heading level1 col5" >199</th>
#       <th class="col_heading level1 col6" >73</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Architecture</th>
#       <th class="index_name level1" >Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3d3c_level0_row0" class="row_heading level0 row0" rowspan="3">LR</th>
#       <th id="T_f3d3c_level1_row0" class="row_heading level1 row0" >Local</th>
#       <td id="T_f3d3c_row0_col0" class="data row0 col0" >0.737 ± 0.028</td>
#       <td id="T_f3d3c_row0_col1" class="data row0 col1" >0.712 ± 0.029</td>
#       <td id="T_f3d3c_row0_col2" class="data row0 col2" >0.821 ± 0.018</td>
#       <td id="T_f3d3c_row0_col3" class="data row0 col3" >0.769 ± 0.029</td>
#       <td id="T_f3d3c_row0_col4" class="data row0 col4" >0.767 ± 0.039</td>
#       <td id="T_f3d3c_row0_col5" class="data row0 col5" >0.677 ± 0.039</td>
#       <td id="T_f3d3c_row0_col6" class="data row0 col6" >0.751 ± 0.021</td>
#     </tr>
#     <tr>
#       <th id="T_f3d3c_level1_row1" class="row_heading level1 row1" >Pooled</th>
#       <td id="T_f3d3c_row1_col0" class="data row1 col0" >0.714 ± 0.023</td>
#       <td id="T_f3d3c_row1_col1" class="data row1 col1" >0.697 ± 0.011</td>
#       <td id="T_f3d3c_row1_col2" class="data row1 col2" >0.684 ± 0.039</td>
#       <td id="T_f3d3c_row1_col3" class="data row1 col3" >0.744 ± 0.034</td>
#       <td id="T_f3d3c_row1_col4" class="data row1 col4" >0.701 ± 0.011</td>
#       <td id="T_f3d3c_row1_col5" class="data row1 col5" >0.683 ± 0.044</td>
#       <td id="T_f3d3c_row1_col6" class="data row1 col6" >0.751 ± 0.021</td>
#     </tr>
#     <tr>
#       <th id="T_f3d3c_level1_row2" class="row_heading level1 row2" >Federated</th>
#       <td id="T_f3d3c_row2_col0" class="data row2 col0" >0.779 ± 0.03</td>
#       <td id="T_f3d3c_row2_col1" class="data row2 col1" >0.749 ± 0.016</td>
#       <td id="T_f3d3c_row2_col2" class="data row2 col2" >0.835 ± 0.014</td>
#       <td id="T_f3d3c_row2_col3" class="data row2 col3" >0.815 ± 0.026</td>
#       <td id="T_f3d3c_row2_col4" class="data row2 col4" >0.802 ± 0.021</td>
#       <td id="T_f3d3c_row2_col5" class="data row2 col5" >0.722 ± 0.038</td>
#       <td id="T_f3d3c_row2_col6" class="data row2 col6" >0.78 ± 0.016</td>
#     </tr>
#     <tr>
#       <th id="T_f3d3c_level0_row3" class="row_heading level0 row3" rowspan="3">MLP</th>
#       <th id="T_f3d3c_level1_row3" class="row_heading level1 row3" >Local</th>
#       <td id="T_f3d3c_row3_col0" class="data row3 col0" >0.693 ± 0.036</td>
#       <td id="T_f3d3c_row3_col1" class="data row3 col1" >0.677 ± 0.016</td>
#       <td id="T_f3d3c_row3_col2" class="data row3 col2" >0.8 ± 0.018</td>
#       <td id="T_f3d3c_row3_col3" class="data row3 col3" >0.76 ± 0.035</td>
#       <td id="T_f3d3c_row3_col4" class="data row3 col4" >0.723 ± 0.028</td>
#       <td id="T_f3d3c_row3_col5" class="data row3 col5" >0.673 ± 0.039</td>
#       <td id="T_f3d3c_row3_col6" class="data row3 col6" >0.709 ± 0.041</td>
#     </tr>
#     <tr>
#       <th id="T_f3d3c_level1_row4" class="row_heading level1 row4" >Pooled</th>
#       <td id="T_f3d3c_row4_col0" class="data row4 col0" >0.718 ± 0.033</td>
#       <td id="T_f3d3c_row4_col1" class="data row4 col1" >0.704 ± 0.025</td>
#       <td id="T_f3d3c_row4_col2" class="data row4 col2" >0.775 ± 0.024</td>
#       <td id="T_f3d3c_row4_col3" class="data row4 col3" >0.744 ± 0.028</td>
#       <td id="T_f3d3c_row4_col4" class="data row4 col4" >0.747 ± 0.032</td>
#       <td id="T_f3d3c_row4_col5" class="data row4 col5" >0.686 ± 0.048</td>
#       <td id="T_f3d3c_row4_col6" class="data row4 col6" >0.708 ± 0.027</td>
#     </tr>
#     <tr>
#       <th id="T_f3d3c_level1_row5" class="row_heading level1 row5" >Federated</th>
#       <td id="T_f3d3c_row5_col0" class="data row5 col0" >0.775 ± 0.027</td>
#       <td id="T_f3d3c_row5_col1" class="data row5 col1" >0.749 ± 0.015</td>
#       <td id="T_f3d3c_row5_col2" class="data row5 col2" >0.833 ± 0.017</td>
#       <td id="T_f3d3c_row5_col3" class="data row5 col3" >0.816 ± 0.03</td>
#       <td id="T_f3d3c_row5_col4" class="data row5 col4" >0.8 ± 0.024</td>
#       <td id="T_f3d3c_row5_col5" class="data row5 col5" >0.72 ± 0.04</td>
#       <td id="T_f3d3c_row5_col6" class="data row5 col6" >0.782 ± 0.017</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Complete Performance Table

# %%
all_perf_dfs = []

lr_local_score_arr = np.empty((4, len(hosps))).astype(str)
lr_pooled_score_arr = np.empty((4, len(hosps))).astype(str)
lr_federated_score_arr = np.empty((4, len(hosps))).astype(str)
mlp_local_score_arr = np.empty((4, len(hosps))).astype(str)
mlp_pooled_score_arr = np.empty((4, len(hosps))).astype(str)
mlp_federated_score_arr = np.empty((4, len(hosps))).astype(str)

for i in range(0, 4):
    for j in range(0, len(hosps)):
        lr_local_score_arr[i, j] = str(lr_local_models_performances[hosps[j]][i][1]) + " ± " + str(lr_local_models_stds[hosps[j]][i][1])
        lr_pooled_score_arr[i, j] = str(lr_agg_local_models_performances[hosps[j]][i][1]) + " ± " + str(lr_agg_local_models_stds[hosps[j]][i][1])
        lr_federated_score_arr[i, j] = str(lr_fed_local_models_performances[hosps[j]][i][1]) + " ± " + str(lr_fed_local_models_stds[hosps[j]][i][1])
lr_score_arr = np.concatenate([lr_local_score_arr, lr_pooled_score_arr, lr_federated_score_arr], axis=0)   
    
    
for i in range(0, 4):
    for j in range(0, len(hosps)):
        mlp_local_score_arr[i, j] = str(mlp_local_models_performances[hosps[j]][i][1]) + " ± " + str(mlp_local_models_stds[hosps[j]][i][1])
        mlp_pooled_score_arr[i, j] = str(mlp_agg_local_models_performances[hosps[j]][i][1]) + " ± " + str(mlp_agg_local_models_stds[hosps[j]][i][1])
        mlp_federated_score_arr[i, j] = str(mlp_fed_local_models_performances[hosps[j]][i][1]) + " ± " + str(mlp_fed_local_models_stds[hosps[j]][i][1])       
mlp_score_arr = np.concatenate([mlp_local_score_arr, mlp_pooled_score_arr, mlp_federated_score_arr], axis=0)           

df_all_lr = pd.DataFrame(lr_score_arr, columns=hosps)
df_all_lr['Type'] = ['Local', 'Local', 'Local', 'Local',
                     'Pooled', 'Pooled', 'Pooled', 'Pooled',
                     'Federated', 'Federated', 'Federated', 'Federated']
df_all_lr['Architecture'] = ['LR', 'LR', 'LR', 'LR',
                            'LR', 'LR', 'LR', 'LR',
                            'LR', 'LR', 'LR', 'LR']
df_all_lr['Metric'] = ['Accuracy', 'AUC', 'Precision', 'Recall',
                      'Accuracy', 'AUC', 'Precision', 'Recall',
                      'Accuracy', 'AUC', 'Precision', 'Recall']
columns = ['Architecture', 'Type', 'Metric'] + hosps
df_all_lr = df_all_lr[columns]

df_all_mlp = pd.DataFrame(mlp_score_arr, columns=hosps)
df_all_mlp['Type'] = ['Local', 'Local', 'Local', 'Local',
                     'Pooled', 'Pooled', 'Pooled', 'Pooled',
                     'Federated', 'Federated', 'Federated', 'Federated']
df_all_mlp['Architecture'] = ['MLP', 'MLP', 'MLP', 'MLP',
                            'MLP', 'MLP', 'MLP', 'MLP',
                            'MLP', 'MLP', 'MLP', 'MLP']
df_all_mlp['Metric'] = ['Accuracy', 'AUC', 'Precision', 'Recall',
                      'Accuracy', 'AUC', 'Precision', 'Recall',
                      'Accuracy', 'AUC', 'Precision', 'Recall']
columns = ['Architecture', 'Type', 'Metric'] + hosps
df_all_mlp = df_all_mlp[columns]

df_perf_hosp = pd.concat([df_all_lr, df_all_mlp])
df_perf_hosp = df_perf_hosp.set_index(['Architecture', 'Type', 'Metric'])

colsR = [('Hospital Sites', col) for col in df_perf_hosp.columns if col in hosps]
df_perf_hosp.columns = pd.MultiIndex.from_tuples(colsR)

# %%
s = df_perf_hosp.style
for idx, group_df in df_perf_hosp.groupby('Type'):
    a = group_df
    s.set_table_styles({('LR', 'Local', 'Accuracy'): [{'selector': '', 'props': 'border-top: 3px solid black;'}]},
                       overwrite=False, axis=1)
    s.set_table_styles({('LR', 'Pooled', 'Accuracy'): [{'selector': '', 'props': 'border-top: 3px solid black;'}]},
                       overwrite=False, axis=1)
    s.set_table_styles({('LR', 'Federated', 'Accuracy'): [{'selector': '', 'props': 'border-top: 3px solid black;'}]},
                       overwrite=False, axis=1)
    s.set_table_styles({('MLP', 'Local', 'Accuracy'): [{'selector': '', 'props': 'border-top: 3px solid black;'}]},
                       overwrite=False, axis=1)
    s.set_table_styles({('MLP', 'Pooled', 'Accuracy'): [{'selector': '', 'props': 'border-top: 3px solid black;'}]},
                       overwrite=False, axis=1)
    s.set_table_styles({('MLP', 'Federated', 'Accuracy'): [{'selector': '', 'props': 'border-top: 3px solid black;'}]},
                       overwrite=False, axis=1)
    s.set_table_styles({('MLP', 'Federated', 'Recall'): [{'selector': '', 'props': 'border-bottom: 3px solid black;'}]},
                       overwrite=False, axis=1)
    s.set_table_styles([{'selector' : '','props' : [('border','3px solid black')]}], 
                      overwrite=False)
    s.set_table_styles([dict(selector='th', props=[('text-align', 'center')])],
                      overwrite=False)
    
s
# Out:
# <style type="text/css">
# #T_d07a7_ .row0 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row4 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row8 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row12 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row16 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row20 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row23 {
#   border-bottom: 3px solid black;
# }
# #T_d07a7_  {
#   border: 3px solid black;
# }
# #T_d07a7_ th {
#   text-align: center;
# }
# #T_d07a7_ .row0 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row4 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row8 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row12 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row16 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row20 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row23 {
#   border-bottom: 3px solid black;
# }
# #T_d07a7_  {
#   border: 3px solid black;
# }
# #T_d07a7_ th {
#   text-align: center;
# }
# #T_d07a7_ .row0 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row4 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row8 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row12 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row16 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row20 {
#   border-top: 3px solid black;
# }
# #T_d07a7_ .row23 {
#   border-bottom: 3px solid black;
# }
# #T_d07a7_  {
#   border: 3px solid black;
# }
# #T_d07a7_ th {
#   text-align: center;
# }
# </style>
# <table id="T_d07a7_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="7">Hospital Sites</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >420</th>
#       <th class="col_heading level1 col1" >122</th>
#       <th class="col_heading level1 col2" >243</th>
#       <th class="col_heading level1 col3" >252</th>
#       <th class="col_heading level1 col4" >458</th>
#       <th class="col_heading level1 col5" >199</th>
#       <th class="col_heading level1 col6" >73</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Architecture</th>
#       <th class="index_name level1" >Type</th>
#       <th class="index_name level2" >Metric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d07a7_level0_row0" class="row_heading level0 row0" rowspan="12">LR</th>
#       <th id="T_d07a7_level1_row0" class="row_heading level1 row0" rowspan="4">Local</th>
#       <th id="T_d07a7_level2_row0" class="row_heading level2 row0" >Accuracy</th>
#       <td id="T_d07a7_row0_col0" class="data row0 col0" >0.744 ± 0.015</td>
#       <td id="T_d07a7_row0_col1" class="data row0 col1" >0.752 ± 0.045</td>
#       <td id="T_d07a7_row0_col2" class="data row0 col2" >0.802 ± 0.016</td>
#       <td id="T_d07a7_row0_col3" class="data row0 col3" >0.778 ± 0.022</td>
#       <td id="T_d07a7_row0_col4" class="data row0 col4" >0.766 ± 0.015</td>
#       <td id="T_d07a7_row0_col5" class="data row0 col5" >0.736 ± 0.037</td>
#       <td id="T_d07a7_row0_col6" class="data row0 col6" >0.78 ± 0.03</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level2_row1" class="row_heading level2 row1" >AUC</th>
#       <td id="T_d07a7_row1_col0" class="data row1 col0" >0.737 ± 0.028</td>
#       <td id="T_d07a7_row1_col1" class="data row1 col1" >0.712 ± 0.029</td>
#       <td id="T_d07a7_row1_col2" class="data row1 col2" >0.821 ± 0.018</td>
#       <td id="T_d07a7_row1_col3" class="data row1 col3" >0.769 ± 0.029</td>
#       <td id="T_d07a7_row1_col4" class="data row1 col4" >0.767 ± 0.039</td>
#       <td id="T_d07a7_row1_col5" class="data row1 col5" >0.677 ± 0.039</td>
#       <td id="T_d07a7_row1_col6" class="data row1 col6" >0.751 ± 0.021</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level2_row2" class="row_heading level2 row2" >Precision</th>
#       <td id="T_d07a7_row2_col0" class="data row2 col0" >0.235 ± 0.023</td>
#       <td id="T_d07a7_row2_col1" class="data row2 col1" >0.179 ± 0.044</td>
#       <td id="T_d07a7_row2_col2" class="data row2 col2" >0.359 ± 0.026</td>
#       <td id="T_d07a7_row2_col3" class="data row2 col3" >0.215 ± 0.026</td>
#       <td id="T_d07a7_row2_col4" class="data row2 col4" >0.254 ± 0.025</td>
#       <td id="T_d07a7_row2_col5" class="data row2 col5" >0.144 ± 0.017</td>
#       <td id="T_d07a7_row2_col6" class="data row2 col6" >0.229 ± 0.022</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level2_row3" class="row_heading level2 row3" >Recall</th>
#       <td id="T_d07a7_row3_col0" class="data row3 col0" >0.57 ± 0.058</td>
#       <td id="T_d07a7_row3_col1" class="data row3 col1" >0.508 ± 0.038</td>
#       <td id="T_d07a7_row3_col2" class="data row3 col2" >0.65 ± 0.027</td>
#       <td id="T_d07a7_row3_col3" class="data row3 col3" >0.588 ± 0.086</td>
#       <td id="T_d07a7_row3_col4" class="data row3 col4" >0.617 ± 0.076</td>
#       <td id="T_d07a7_row3_col5" class="data row3 col5" >0.475 ± 0.088</td>
#       <td id="T_d07a7_row3_col6" class="data row3 col6" >0.59 ± 0.053</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level1_row4" class="row_heading level1 row4" rowspan="4">Pooled</th>
#       <th id="T_d07a7_level2_row4" class="row_heading level2 row4" >Accuracy</th>
#       <td id="T_d07a7_row4_col0" class="data row4 col0" >0.743 ± 0.03</td>
#       <td id="T_d07a7_row4_col1" class="data row4 col1" >0.829 ± 0.013</td>
#       <td id="T_d07a7_row4_col2" class="data row4 col2" >0.77 ± 0.027</td>
#       <td id="T_d07a7_row4_col3" class="data row4 col3" >0.834 ± 0.019</td>
#       <td id="T_d07a7_row4_col4" class="data row4 col4" >0.781 ± 0.04</td>
#       <td id="T_d07a7_row4_col5" class="data row4 col5" >0.82 ± 0.025</td>
#       <td id="T_d07a7_row4_col6" class="data row4 col6" >0.789 ± 0.028</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level2_row5" class="row_heading level2 row5" >AUC</th>
#       <td id="T_d07a7_row5_col0" class="data row5 col0" >0.714 ± 0.023</td>
#       <td id="T_d07a7_row5_col1" class="data row5 col1" >0.697 ± 0.011</td>
#       <td id="T_d07a7_row5_col2" class="data row5 col2" >0.684 ± 0.039</td>
#       <td id="T_d07a7_row5_col3" class="data row5 col3" >0.744 ± 0.034</td>
#       <td id="T_d07a7_row5_col4" class="data row5 col4" >0.701 ± 0.011</td>
#       <td id="T_d07a7_row5_col5" class="data row5 col5" >0.683 ± 0.044</td>
#       <td id="T_d07a7_row5_col6" class="data row5 col6" >0.751 ± 0.021</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level2_row6" class="row_heading level2 row6" >Precision</th>
#       <td id="T_d07a7_row6_col0" class="data row6 col0" >0.235 ± 0.021</td>
#       <td id="T_d07a7_row6_col1" class="data row6 col1" >0.213 ± 0.009</td>
#       <td id="T_d07a7_row6_col2" class="data row6 col2" >0.275 ± 0.032</td>
#       <td id="T_d07a7_row6_col3" class="data row6 col3" >0.253 ± 0.043</td>
#       <td id="T_d07a7_row6_col4" class="data row6 col4" >0.24 ± 0.031</td>
#       <td id="T_d07a7_row6_col5" class="data row6 col5" >0.188 ± 0.027</td>
#       <td id="T_d07a7_row6_col6" class="data row6 col6" >0.236 ± 0.019</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level2_row7" class="row_heading level2 row7" >Recall</th>
#       <td id="T_d07a7_row7_col0" class="data row7 col0" >0.573 ± 0.093</td>
#       <td id="T_d07a7_row7_col1" class="data row7 col1" >0.379 ± 0.044</td>
#       <td id="T_d07a7_row7_col2" class="data row7 col2" >0.457 ± 0.051</td>
#       <td id="T_d07a7_row7_col3" class="data row7 col3" >0.457 ± 0.059</td>
#       <td id="T_d07a7_row7_col4" class="data row7 col4" >0.459 ± 0.07</td>
#       <td id="T_d07a7_row7_col5" class="data row7 col5" >0.381 ± 0.042</td>
#       <td id="T_d07a7_row7_col6" class="data row7 col6" >0.586 ± 0.059</td>
#     </tr>
#     <tr>
#       <th id="T_d07a7_level1_row8" class="row_heading level1 row8" rowspan="4">Federa
